# %% [markdown]
# # Markdown Cell Example
# markdown can be readibly interleaved and dispersed between code in notebooks
# ## Explanation of code below
# The histogram (x-axis) binned readability score, (y-axis) counts of papers that occupy that readability score.
#
# The histogram is initially populated exclusively by the ART corpus, but the idea was every time a new author got scraped from scholar, it would be added in, such that with each persons new search our big picture of science readability would be better informed.
#
# So the histogram changes a little modestly perceptible amount with the author scrape, but three dots pertaining to the authors easiest read, hardest read, and mean read where added.
#
# These used to be ```[mean-standard dev, mean, mean+standard dev]``` but there was a flaw implementing that. It could just be that the plot looked way too busy around the mean, and it was harder to look at.
#
# There is an issue with getting the dots to appear in the centre of histogram bins. I was working under the assumption, that if I knew the ```[min,mean,max]```, readability scores for Rick Gerkin, I could add to them half the bin width, and dot's would be centred. That is almost correct. I forgot that these calculations are not performed on pre binned data, so the x-coordinates of ```[min,mean,max]``` need to be slightly shifted to the nearest histogram bin start first.
#
# Think of it as a bit like snapping something to a grid in photoshop.

# %% [markdown]
# It should be easy to hack this code to run off a local machine, using sudo.
# Set up the Environment. This is now done in requirements, and the postBuild script.
# ```python
# !pip install matplotlib
# !pip install pandas
# !pip install seaborn
#
# if os.path.exists('traingDats.p?dl=0'):
#     pass
#
# else:
#     !wget https://www.dropbox.com/s/3h12l5y2pn49c80/traingDats.p?dl=0
#     !wget https://www.dropbox.com/s/crarli3772rf3lj/more_authors_results.p?dl=0
#     !wget https://www.dropbox.com/s/x66zf52himmp5ox/benchmarks.p?dl=0
# ```

# %%
import pickle
import copy
import matplotlib as mpl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import plotly as py

# %%
try:
    with open('scraped_new.p?dl=0','rb') as f:
        texts = pickle.load(f) 
except:
    # !wget https://www.dropbox.com/s/1kc7alp79h701hx/scraped_new.p?dl=0
    with open('scraped_new.p?dl=0','rb') as f:
        texts = pickle.load(f) 

queries = set([t['query'] for t in texts ])
temp = [t for t in texts if 'standard' in t.keys() and 'wikipedia' in t['link']]
science = ['cancer','Vaccines','evolution','climate change','Transgenic','photosysnthesis','evolution','GMO']
res = [t['standard'] for t in temp if t['query'] in science]
#res = [t['standard'] for t in temp]# if t['query'] in science]

mwp = np.mean(res)  
abstract_wiki = {'standard':mwp}

# %%
with open('traingDats.p?dl=0','rb') as f:
        trainingDats = pickle.load(f) 

bmark = pickle.load(open('benchmarks.p?dl=0','rb'))
#bmark.append(abstract_wiki)
NAME,ar = pickle.load(open('more_authors_results.p?dl=0','rb'))
NAME = NAME[0]
trainingDats.extend(bmark)

# %%
def get_heights(stats_items,histogram_content,x_sub_set):
    vertical_postions_indexs = []
    for i in stats_items:
        vertical_postions_indexs.append(find_nearest(histogram_content, i))
    bin_width_offset = (xys[1][0] - xys[0][0])/2.0
    x_sub_set = [ i+bin_width_offset for i in x_sub_set ]


    heights = []
    for i in vertical_postions_indexs:
        heights.append(xys[i][1])
    return heights, bin_width_offset


def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

def snap_to_grid(author_stats,bin_centers):
    author_stats_grid = []
    for as_ in author_stats:
        as_ = find_nearest(bin_centers,as_)
        author_stats_grid.append(bin_centers[as_])
    return author_stats_grid

# %%
max_ART = np.max([ t['standard'] for t in trainingDats ])
publication = [ t['publication'] for t in trainingDats if t['standard'] == max_ART ]
keys = [ t.keys() for t in trainingDats if t['standard'] == max_ART ]

fname = [ t['file_name'] for t in trainingDats if t['standard'] == max_ART ]
bmark_max_art = {'standard':max_ART}
#max_ART

# %%
standard_sci = [ t['standard'] for t in trainingDats ]
ar = [ t for t in ar if type(t) is type({})]
ar = [ t for t in ar if 'standard' in t.keys()]
xys = [ (h.get_x(),h.get_height()) for h in sns.distplot(standard_sci).patches ]

x_grid = [ h.get_x() for h in sns.distplot(standard_sci).patches ]
offset = float((x_grid[1] - x_grid[0])/2.0)
bin_centers = [gr+offset for gr in x_grid]
# this plot not used yet.

fig = plt.figure(figsize=(10, 8), dpi=80)
ax1 = fig.add_subplot(111)#)
mean_ = np.mean([a['standard'] for a in ar])
min_ = np.min([a['standard'] for a in ar])
max_ = np.max([a['standard'] for a in ar])
std_ = np.std([a['standard'] for a in ar])
stats_items = [mean_,min_,max_]

g = sns.distplot(standard_sci, label="Readability Index")


histogram_content = [x[0] for x in xys]
height_content = np.array([x[1] for x in xys])

hc = np.array(histogram_content)

x_sub_set=histogram_content


other_name=str('Phytochromobilin C15-Z,syn - C15-E,anti isomerization: concerted or stepwise?')
worst_height,_ = get_heights([max_ART],hc,x_sub_set)
mwp_height,_ = get_heights([mwp],hc,x_sub_set)

#bmark_max_art
worst_height = worst_height[0]
#bmark_stats_items_grid = snap_to_grid(bmark_stats_items,bin_centers)

#worst_distamnce = snap_to_grid(max_ART,bin_centers)
worst_distance = snap_to_grid([max_ART],bin_centers)
mwp_distance = snap_to_grid([mwp],bin_centers)


bmark_stats_items = [ b['standard'] for b in bmark ]
#bmark_stats_items.append(max_ART)
categories = ["upgoer 5", "Readibility Declining Over Time","Science of Writing","Post Modern Essay Generator"]#"Mean Wikipedia"]#,other_name]# "wikipedia science"]
bmark_heights, _ = get_heights(bmark_stats_items,histogram_content,x_sub_set)
heights, bwo = get_heights(stats_items,histogram_content,x_sub_set)
#bmark_heights.append(worst_height)
bmark_stats_items = [i+bwo for i in bmark_stats_items]
mean_a = mean_
min_a = min_ 
max_a = max_ 
xticks = list(range(0,45,5))

#print(xticks)
bmark_stats_items
# Out:
# [6.484375, 8.484375, 14.484375, 16.484375, 8.484375, 16.484375]

# %%
bmark_stats_items_grid = snap_to_grid(bmark_stats_items,bin_centers)
author_stats =[i for i in [mean_,min_,max_]]
author_stats_grid = snap_to_grid(author_stats,bin_centers)
mean_a_grid = snap_to_grid([mean_a],bin_centers)
x_sub_set_grid = snap_to_grid(x_sub_set,bin_centers)

# %%
recalibrate_heights,b = get_heights(author_stats_grid,hc,x_sub_set)

heights[0] = np.max(recalibrate_heights)
heights[2] = recalibrate_heights[2]

# %%
np.max(height_content)
heights
# Out:
# [0.21449518223711772, 0.01787459851975981, 0.008937299259879905]

# %%
bmark_heights
print(len(bmark_heights))
print(len(bin_centers))
print(len(bmark_stats_items))
# Out:
# 6
# 64
# 6

# %%
print(len(bmark_stats_items_grid))
# Out:
# 6

# %%
fig = plt.figure(figsize=(9, 9), dpi=100)
ax1 = fig.add_subplot(111)#)
g = sns.distplot(standard_sci, label="Readability Index")

benchmarks = pd.DataFrame({
'benchmarks': bmark_stats_items_grid,
    'CDF': bmark_heights
    })


data0 = pd.DataFrame({
'mean, min, maximum': author_stats_grid,
    'CDF': heights
    })


data2 = pd.DataFrame({
'Standard Reading Level': mean_a_grid,
    'CDF': np.max(height_content)
    })




legend_properties = {'weight':'bold','size':8}

ax = sns.regplot(data=benchmarks, x="benchmarks", y="CDF", fit_reg=False, marker="o", color="green")


ax = sns.regplot(data=data0, x="mean, min, maximum", y="CDF", fit_reg=False, marker="o", color="blue")
#ax = sns.regplot(x='Standard Reading Level', y='CDF',data=data1, fit_reg=False, marker="o", color="green")#, data=fmri)
ax = sns.regplot(data=data2, x="Standard Reading Level", y="CDF", fit_reg=False, marker="o", color="red")

legendMain=ax.legend(labels=[str("std deviation")], prop=legend_properties,loc='upper right')

legendSide0=ax.legend(labels=[NAME],prop=legend_properties,loc='center right')
legendSide1=ax.legend(labels=[str('Number of Documents: '+str(len(ar)))],prop=legend_properties,loc='upper left')


legendMain=ax.legend(labels=[str("Google scholar author relative to ART Corpus distribution. Total docs: ")+str(len(trainingDats))], prop=legend_properties,loc='upper left')


#for i,j,k in zip(author_stats_grid,heights,[str(NAME)+' mean',str(NAME)+' min',str(NAME)+' max']):

xinterval = author_stats_grid
xinterval.extend(bmark_stats_items_grid)
#xinterval.append(other)
#coords = copy.copy([item for item in ax.get_xticklabels()])
x1,y1,z1 = (mwp_distance[0],mwp_height[0],str('mean wikipedia'))
xinterval.insert(4,x1)
ax.set_xticks(xinterval)

new_categories = []
new_categories.extend([str(NAME)+' mean',str(NAME)+' min',str(NAME)+' max'])
new_categories.extend(categories)
new_categories.insert(4,'Mean Wikipedia Biological Science')
x,y,z = (worst_distance[0],worst_height,other_name)

data3 = pd.DataFrame({
'Standard Reading Level': [x1],
    'CDF': [y1]
    })
ax = sns.regplot(data=data3, x='Standard Reading Level', y="CDF", fit_reg=False, marker="o", color="green")

#new_categories.append(other_name)

ax.set_xticklabels(new_categories, minor=False, rotation=90)
ax.set_xticklabels(new_categories, minor=True, rotation=0)

ax = sns.regplot(data=benchmarks, x="benchmarks", y="CDF", fit_reg=False, marker="o", color="green")

# Get the two lines from the axes to generate shading
l1 = ax.lines[0]
#l2 = ax.lines[1]

# Get the xy data from the lines so that we can shade
x1_ = l1.get_xydata()[:,0]
y1 = l1.get_xydata()[:,1]
x1=[mean_-std_,mean_+std_]
index_0 = find_nearest(x1[0],x1_)
index_1 = find_nearest(x1[1],x1_)

reducedx = x1_[index_0:index_1]
reducedy = y1[index_0:index_1]

print(x1_)
ax.fill_between(reducedx,reducedy, color="red", alpha=0.1)
#ax.fill_between(x2,y2, color="blue", alpha=0.3)
ax2 = plt.twiny()
xticks = list(range(0,45,5))

plt.xticks(xticks)
#ax2.xaxis.set_minor_locator(AutoMinorLocator(4))
plt.tick_params(axis="y", labelcolor="r", pad=8)




#ax.text(x-0.25,y+0.005,z, rotation=90)  


#ax.text(x1,y1,z1, rotation=90)  

    
plt.savefig(str(NAME)+'_author_readability.png')
plt.show()
# Out:
# [ 2.74271404  3.12164911  3.50058418  3.87951925  4.25845432  4.63738939
#   5.01632446  5.39525953  5.7741946   6.15312967  6.53206474  6.91099981
#   7.28993488  7.66886995  8.04780502  8.42674009  8.80567516  9.18461023
#   9.5635453   9.94248037 10.32141544 10.70035051 11.07928558 11.45822065
#  11.83715572 12.21609079 12.59502586 12.97396093 13.352896   13.73183107
#  14.11076614 14.48970121 14.86863628 15.24757135 15.62650642 16.00544149
#  16.38437656 16.76331163 17.1422467  17.52118177 17.90011684 18.27905191
#  18.65798698 19.03692205 19.41585712 19.79479219 20.17372726 20.55266233
#  20.9315974  21.31053247 21.68946753 22.0684026  22.44733767 22.82627274
#  23.20520781 23.58414288 23.96307795 24.34201302 24.72094809 25.09988316
#  25.47881823 25.8577533  26.23668837 26.61562344 26.99455851 27.37349358
#  27.75242865 28.13136372 28.51029879 28.88923386 29.26816893 29.647104
#  30.02603907 30.40497414 30.78390921 31.16284428 31.54177935 31.92071442
#  32.29964949 32.67858456 33.05751963 33.4364547  33.81538977 34.19432484
#  34.57325991 34.95219498 35.33113005 35.71006512 36.08900019 36.46793526
#  36.84687033 37.2258054  37.60474047 37.98367554 38.36261061 38.74154568
#  39.12048075 39.49941582 39.87835089 40.25728596]

# %%
plt.savefig(str(NAME)+'_author_readability.png')

new_categories
x,y,z = (worst_distance[0],worst_height,other_name)
x
y
z
# Out:
# 'Phytochromobilin C15-Z,syn - C15-E,anti isomerization: concerted or stepwise?'

# %%
x,y,z = (mwp_distance[0],mwp_height[0],str('mean wikipedia'))

# %%
xticks
xinterval
# Out:
# [18.109375,
#  13.265625,
#  25.859375,
#  6.484375,
#  15.203125,
#  8.421875,
#  14.234375,
#  16.171875,
#  8.421875,
#  16.171875]

# %%
data2
# Out:
#    Standard Reading Level       CDF
# 0               18.109375  0.214495

# %%
data0
# Out:
#    mean, min, maximum       CDF
# 0           18.109375  0.214495
# 1           13.265625  0.017875
# 2           25.859375  0.008937

# %%
bmark_stats_items
# Out:
# [6.484375, 8.484375, 14.484375, 16.484375, 8.484375, 16.484375]

# %%
#bmark

# %%
trainingDats[-1]
# Out:
# {'link': 'nicholas',
#  'page_rank': 'nicholas',
#  'wcount': 3593,
#  'tokens': ['understanding',
#   'climate',
#   'change',
#   'gregory',
#   'nicholas',
#   'v',
#   '1',
#   '30',
#   'aug',
#   '2019',
#   '1',
#   '.',
#   'introduction',
#   'in',
#   '2019',
#   ',',
#   'newspapers',
#   'magazines',
#   'publishing',
#   'reports',
#   'subject',
#   'climate',
#   'change',
#   '.',
#   'it',
#   'appears',
#   'scientific',
#   'meteorological',
#   'bodies',
#   'see',
#   'climate',
#   'change',
#   'major',
#   'problem',
#   'humankind',
#   '(',
#   'species',
#   ')',
#   ',',
#   'concerted',
#   'action',
#   'needed',
#   'immediately',
#   'prevent',
#   'disaster',
#   ',',
#   'principally',
#   'reducing',
#   'emissions',
#   'greenhouse',
#   'gases',
#   '.',
#   'however',
#   'politicians',
#   'administrative',
#   'structures',
#   'difficulty',
#   'understanding',
#   'nature',
#   'problem',
#   '(',
#   'except',
#   'perhaps',
#   'europeans',
#   ')',
#   'seem',
#   'hurry',
#   'follow',
#   'recommendations',
#   'scientists',
#   '.',
#   'i',
#   'believe',
#   'people',
#   'clear',
#   'understanding',
#   'problem',
#   'scientific',
#   'community',
#   'somehow',
#   'unable',
#   '?',
#   'rephrase',
#   'explain',
#   'reasoning',
#   'form',
#   'understood',
#   'man',
#   'eg',
#   '‘',
#   'lay',
#   'street',
#   '.',
#   'they',
#   'expect',
#   'us',
#   'take',
#   'word',
#   'without',
#   'understanding',
#   'audience',
#   '’',
#   'thisextremelyseriousmatterourselves',
#   '.',
#   'when',
#   'one',
#   'reads',
#   'technical',
#   'literature',
#   'subject',
#   ',',
#   'much',
#   'seems',
#   'transparent',
#   'scientific',
#   'background',
#   '.',
#   'i',
#   'therefore',
#   'attempting',
#   'essay',
#   'go',
#   'back',
#   'scratch',
#   'build',
#   'component',
#   'knowledge',
#   'arguments',
#   'form',
#   'easily',
#   'understood',
#   '.',
#   'be',
#   'warned',
#   ',',
#   'however',
#   '!',
#   'it',
#   'simple',
#   'task',
#   ',',
#   'many',
#   'scientific',
#   'concepts',
#   'involved',
#   '.',
#   'the',
#   'literature',
#   'subject',
#   ',',
#   'much',
#   'available',
#   'reputable',
#   'internet',
#   'sites',
#   ',',
#   'falls',
#   'following',
#   'categories',
#   ':',
#   'international',
#   'bodies',
#   '(',
#   'international',
#   'panel',
#   'climate',
#   'change',
#   ')',
#   ';',
#   'national',
#   'bodies',
#   '(',
#   'australian',
#   'meteorological',
#   'bureau',
#   ',',
#   'csiro',
#   ',',
#   'climate',
#   'change',
#   'authority',
#   ')',
#   ';',
#   'state',
#   'government',
#   'bodies',
#   'universities',
#   ';',
#   'miscellaneous',
#   'websites',
#   ',',
#   'dubious',
#   '.',
#   'in',
#   'study',
#   'i',
#   'drawn',
#   'selection',
#   'reputable',
#   'web',
#   'based',
#   'material',
#   'also',
#   'readily',
#   'available',
#   'textbooks',
#   '.',
#   '2',
#   '.',
#   'setting',
#   'scene',
#   '–',
#   'what',
#   'makes',
#   'planet',
#   'special',
#   '?',
#   'let',
#   'us',
#   'start',
#   'basics',
#   'earth',
#   '’',
#   'climate',
#   ',',
#   'looking',
#   'firstly',
#   'planet',
#   '’',
#   'rotation',
#   'orbit',
#   'around',
#   'sun',
#   '(',
#   'see',
#   'diagram',
#   ')',
#   '.',
#   'orbit',
#   'orientation',
#   'earth',
#   'our',
#   'earth',
#   'rotates',
#   'axis',
#   ',',
#   'giving',
#   'us',
#   'cycle',
#   'day',
#   'night',
#   '.',
#   'it',
#   'also',
#   'moves',
#   'space',
#   'around',
#   'sun',
#   'approximately',
#   'circular',
#   'orbit',
#   '.',
#   'because',
#   'its',
#   'axis',
#   'tilted',
#   ',',
#   'illuminated',
#   'area',
#   'shifts',
#   'north',
#   'south',
#   'back',
#   'earth',
#   '’',
#   'passage',
#   'around',
#   'sun',
#   ',',
#   'experience',
#   'seasons',
#   '.',
#   'the',
#   'intensity',
#   'sun',
#   '’',
#   'rays',
#   'strongest',
#   'tropics',
#   'directly',
#   'face',
#   'sun',
#   ',',
#   'weakest',
#   'polar',
#   'areas',
#   '.',
#   'in',
#   'solar',
#   'system',
#   ',',
#   'planet',
#   'earth',
#   'placed',
#   'fortunate',
#   'location',
#   '.',
#   'the',
#   'next',
#   'outermost',
#   'planet',
#   'mars',
#   'barren',
#   ',',
#   'thin',
#   'atmosphere',
#   ',',
#   'without',
#   'water',
#   'cold',
#   'surface',
#   '.',
#   'the',
#   'next',
#   'innermost',
#   'planet',
#   'venus',
#   'dense',
#   'poisonous',
#   'atmosphere',
#   ',',
#   'surface',
#   'extremely',
#   'hot',
#   '.',
#   'but',
#   'earth',
#   'blessed',
#   'atmosphere',
#   'able',
#   'support',
#   'life',
#   ',',
#   'existence',
#   'large',
#   'quantities',
#   'water',
#   'form',
#   'oceans',
#   '.',
#   'its',
#   'surface',
#   'temperature',
#   'determined',
#   'incoming',
#   'radiation',
#   'sun',
#   ',',
#   'surface',
#   'characteristics',
#   'land',
#   'masses',
#   'seas',
#   ',',
#   'nature',
#   'gases',
#   'make',
#   'atmosphere',
#   '(',
#   'nitrogen',
#   ',',
#   'oxygen',
#   'others',
#   ')',
#   '.',
#   'conditions',
#   'earth',
#   '’',
#   'surface',
#   'largely',
#   'determined',
#   'atmosphere',
#   '.',
#   'the',
#   'atmosphere',
#   'made',
#   'layers',
#   ',',
#   'shown',
#   'diagram',
#   '.',
#   'the',
#   'troposphere',
#   ',',
#   'average',
#   '11',
#   'km',
#   'thick',
#   '(',
#   '16',
#   'km',
#   'thick',
#   'equator',
#   '8',
#   'km',
#   'poles',
#   ')',
#   '.this',
#   'region',
#   'contains',
#   '90',
#   '%',
#   'atmosphere',
#   '’',
#   'mass',
#   '.',
#   'it',
#   'region',
#   'pressure',
#   'differences',
#   ',',
#   'winds',
#   ',',
#   'vertical',
#   'convection',
#   'currents',
#   ',',
#   'water',
#   'evaporation',
#   'condensation',
#   'take',
#   'place',
#   '.',
#   'the',
#   'stratosphere',
#   ',',
#   'extends',
#   '50',
#   'km',
#   '.',
#   'a',
#   'brief',
#   'sentence',
#   'mesosphere',
#   'thermosphere',
#   'would',
#   'helpful',
#   'mentioned',
#   'diagram',
#   '.',
#   'beyond',
#   'stratosphere',
#   'atmosphere',
#   'becomes',
#   'thinner',
#   'thinner',
#   'increasing',
#   'altitude',
#   ',',
#   'definite',
#   'boundary',
#   'atmosphere',
#   'outer',
#   'space',
#   '.',
#   'earth',
#   '’',
#   'magnetic',
#   'field',
#   'serves',
#   'deflect',
#   'solar',
#   'wind',
#   ',',
#   'whose',
#   'charged',
#   'particles',
#   'would',
#   'otherwise',
#   'strip',
#   'away',
#   'ozone',
#   'layer',
#   ',',
#   'extends',
#   '15',
#   'km',
#   '35',
#   'km',
#   'altitude',
#   'protects',
#   'earth',
#   'harmful',
#   'x',
#   'rays',
#   'ultraviolet',
#   'radiation',
#   '.',
#   'the',
#   'atmosphere',
#   'earth',
#   'protects',
#   'life',
#   'earth',
#   'creating',
#   'sufficient',
#   'pressure',
#   'allow',
#   'liquid',
#   'water',
#   'exist',
#   'earth',
#   '’',
#   'surface',
#   ';',
#   'absorbing',
#   'ultraviolet',
#   'radiation',
#   ';',
#   'warming',
#   'surface',
#   'heat',
#   'retention',
#   'reducing',
#   'temperature',
#   'extremes',
#   'day',
#   'night',
#   '.',
#   '3',
#   '.',
#   'energy',
#   'flow',
#   'earth',
#   'atmosphere',
#   'the',
#   'earth',
#   '’',
#   'climate',
#   'determined',
#   'primarily',
#   'energy',
#   'flows',
#   'sun',
#   ',',
#   'earth',
#   '’',
#   'surface',
#   'atmosphere',
#   '.',
#   'it',
#   'important',
#   'note',
#   ',',
#   'stable',
#   'temperature',
#   'conditions',
#   ',',
#   'total',
#   'energy',
#   'received',
#   'radiant',
#   'form',
#   'sun',
#   'must',
#   'balanced',
#   'total',
#   'energy',
#   'outgoing',
#   'radiation',
#   'emitted',
#   'space',
#   '.',
#   'in',
#   'diagram',
#   ',',
#   'energy',
#   'flows',
#   'average',
#   'values',
#   'surface',
#   'earth',
#   'period',
#   'year',
#   '.',
#   'but',
#   'need',
#   'concern',
#   'unduly',
#   'numerical',
#   'values',
#   'diagram',
#   '!',
#   'section',
#   '7',
#   'details',
#   'range',
#   'electromagnetic',
#   'radiation',
#   'wavelengths',
#   'involved',
#   '.',
#   'in',
#   'general',
#   'terms',
#   ',',
#   'radiation',
#   'sun',
#   ',',
#   'high',
#   'temperature',
#   ',',
#   'shortwave',
#   'category',
#   ',',
#   'i.e',
#   '.',
#   'short',
#   'wavelength',
#   ',',
#   'high',
#   'energy',
#   'content',
#   '.',
#   'the',
#   'surface',
#   'land',
#   'areas',
#   'oceans',
#   'lower',
#   'temperature',
#   ',',
#   'therefore',
#   'emit',
#   'radiation',
#   'longer',
#   'wavelengths',
#   '(',
#   'longwave',
#   'radiation',
#   ')',
#   'lower',
#   'energy',
#   'content',
#   '.',
#   'note',
#   'made',
#   'amount',
#   'infrared',
#   'radiation',
#   '(',
#   'shown',
#   'back',
#   'radiation',
#   ')',
#   'directed',
#   'atmosphere',
#   'back',
#   'surface',
#   ',',
#   'keeping',
#   'us',
#   'warm',
#   '.',
#   'average',
#   'global',
#   'energy',
#   'flows',
#   'on',
#   'short',
#   'timescale',
#   ',',
#   'distribution',
#   'incoming',
#   'energy',
#   'sun',
#   'influenced',
#   'patterns',
#   'circulating',
#   'wind',
#   'currents',
#   'around',
#   'globe',
#   '.',
#   'these',
#   'patterns',
#   'determined',
#   'rotation',
#   'earth',
#   'around',
#   'axis',
#   '(',
#   'see',
#   'diagram',
#   ')',
#   '.',
#   'it',
#   'apparent',
#   'atmospheric',
#   'wind',
#   'patterns',
#   'northern',
#   'hemisphere',
#   'essentially',
#   'separated',
#   'southern',
#   'hemisphere',
#   '.',
#   'on',
#   'longer',
#   'timescale',
#   ',',
#   'energy',
#   'transferred',
#   'patterns',
#   'ocean',
#   'currents',
#   '.',
#   'whilst',
#   'also',
#   'driven',
#   'rotation',
#   'earth',
#   ',',
#   'contained',
#   'boundaries',
#   'land',
#   'masses',
#   'depths',
#   'oceans',
#   '.',
#   'major',
#   'wind',
#   'patterns',
#   'major',
#   'ocean',
#   'currents',
#   '4',
#   '.',
#   'the',
#   'constituents',
#   'atmosphere',
#   'let',
#   'us',
#   'look',
#   'component',
#   'gases',
#   'make',
#   'atmosphere',
#   '.',
#   'the',
#   'atmosphere',
#   '(',
#   'dry',
#   'air',
#   ')',
#   'following',
#   'major',
#   'constituent',
#   'gases',
#   ':',
#   'nitrogen',
#   ':',
#   '781',
#   ',',
#   '000',
#   'parts',
#   'per',
#   'million',
#   'volume',
#   '(',
#   'ppm',
#   'average',
#   ')',
#   'oxygen',
#   ':',
#   '209,000',
#   'ppm',
#   'av',
#   'argon',
#   ':',
#   '9,300',
#   'ppm',
#   'av',
#   'carbon',
#   'dioxide',
#   ':',
#   '400',
#   'ppm',
#   'av',
#   'neon',
#   ':',
#   '18',
#   'ppm',
#   'av',
#   'helium',
#   ':',
#   '5',
#   'ppm',
#   'av',
#   'methane',
#   ':',
#   '2',
#   'ppm',
#   'av',
#   'these',
#   'concentrations',
#   'maintained',
#   'steady',
#   '10',
#   'km',
#   'altitude',
#   '.',
#   'the',
#   'original',
#   'presence',
#   'nitrogen',
#   'carbon',
#   'dioxide',
#   'atmosphere',
#   'thought',
#   'arisen',
#   'volcanism',
#   ',',
#   'together',
#   'impact',
#   'huge',
#   'asteroids',
#   '(',
#   'carrying',
#   'ammonia',
#   ')',
#   'early',
#   'earth',
#   '’',
#   'history',
#   '.',
#   'the',
#   'oxygen',
#   'originates',
#   'form',
#   'living',
#   'organisms',
#   '(',
#   'algae',
#   ',',
#   'plankton',
#   'plant',
#   'life',
#   'thre',
#   'land',
#   'areas',
#   ')',
#   ',',
#   'via',
#   'process',
#   'photosynthesis',
#   '.',
#   'oxygen',
#   'thought',
#   'first',
#   'produced',
#   'around',
#   '2.8',
#   'billion',
#   'years',
#   'ago',
#   '.',
#   'in',
#   'addition',
#   ',',
#   'water',
#   'vapour',
#   'present',
#   '0.25',
#   '%',
#   'mass',
#   'full',
#   'atmosphere',
#   '.',
#   'locally',
#   'vary',
#   '100',
#   'ppm',
#   '4200ppm',
#   'volume',
#   ',',
#   'depending',
#   'local',
#   'temperature',
#   '.',
#   'its',
#   'concentration',
#   'highest',
#   'tropical',
#   'latitudes',
#   ',',
#   'varies',
#   'strongly',
#   'locally',
#   'throughout',
#   '.',
#   'the',
#   'presence',
#   'water',
#   'vapour',
#   'air',
#   'naturally',
#   'dilutes',
#   'displaces',
#   'air',
#   'components',
#   'concentration',
#   'increases',
#   '.',
#   'water',
#   'vapour',
#   'lower',
#   'density',
#   'air',
#   'therefore',
#   'buoyant',
#   'atmosphere',
#   '.',
#   'its',
#   'mean',
#   'global',
#   'content',
#   'roughly',
#   'sufficient',
#   'cover',
#   'entire',
#   'surface',
#   'planet',
#   'layer',
#   'liquid',
#   'depth',
#   '25',
#   'mm',
#   '.',
#   'approximately',
#   '99',
#   '%',
#   'earth',
#   '’',
#   'water',
#   'vapour',
#   'contained',
#   'within',
#   'troposphere',
#   '.',
#   'its',
#   'condensation',
#   'liquid',
#   'solid',
#   'form',
#   'responsible',
#   'clouds',
#   ',',
#   'rain',
#   ',',
#   'snow',
#   'precipitation',
#   ',',
#   'count',
#   'amongst',
#   'significant',
#   'elements',
#   'experience',
#   'weather',
#   '.',
#   'less',
#   'obviously',
#   ',',
#   'latent',
#   'heat',
#   'vaporisation',
#   ',',
#   'released',
#   'atmosphere',
#   'whenever',
#   'condensation',
#   'occurs',
#   ',',
#   'one',
#   'important',
#   'terms',
#   'atmospheric',
#   'energy',
#   'budget',
#   'local',
#   'global',
#   'scales',
#   '.',
#   'for',
#   'example',
#   ',',
#   'latent',
#   'heat',
#   'release',
#   ...],
#  'perplexity': None,
#  'publication': {},
#  'clue_words': ['volume', 'nature', 'article'],
#  'clue_links': [],
#  'science': False,
#  'wiki': False,
#  'uniqueness': 0.37306172088780787,
#  'info_density': 0.0006726645926175061,
#  'sp': 0.0730123687858983,
#  'ss': 0.4008192815898699,
#  'sp_norm': 0.0730123687858983,
#  'ss_norm': 0.4008192815898699,
#  'gf': 15.72,
#  'standard': 16.0,
#  'scaled': 0.004453103256331756,
#  'conciseness': 8.03688862445894,
#  'penalty': 8.01378057590509}
